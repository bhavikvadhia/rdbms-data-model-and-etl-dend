# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql select start_time,user_id,level,song_id,artist_id,session_id,location,user_agent,count(*) from songplays group by start_time,user_id,level,song_id,artist_id,session_id,location,user_agent having count(*) > 1;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 0 rows affected.
# []

# %%
# %sql SELECT * from users where user_id = 80;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(80, 'Tegan', 'Levine', 'F', 'paid')]

# %%
# %sql SELECT * FROM songs;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 71 rows affected.
# [('SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', None, 218.93179),
#  ('SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, 148.03546),
#  ('SOXVLOJ12AB0189215', 'Amor De Cabaret', 'ARKRRTF1187B9984DA', None, 177.47546),
#  ('SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233.40363),
#  ('SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099', 2007, 209.60608),
#  ('SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', None, 267.7024),
#  ('SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', None, 114.78159),
#  ('SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', None, 189.57016),
#  ('SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 269.81832),
#  ('SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', None, 266.39628),
# ...

# %%
# %sql SELECT * FROM artists;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 69 rows affected.
# [('ARD7TVE1187B99BFB1', 'Casual', 'California - LA', None, None),
#  ('ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35.14968, -90.04892),
#  ('ARKRRTF1187B9984DA', 'Sonora Santanera', None, None, None),
#  ('AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', None, None),
#  ('ARXR32B1187FB57099', 'Gob', None, None, None),
#  ('ARKFYS91187B98E58F', 'Jeff And Sheri Easter', None, None, None),
#  ('ARD0S291187B9B7BF5', 'Rated R', 'Ohio', None, None),
#  ('AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', None, None),
#  ('AR8ZCNI1187B9A069B', 'Planet P Project', None, None, None),
#  ('ARNTLGG11E2835DDB9', 'Clp', None, None, None),
#  ('ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.21962, -80.01955),
#  ('ARC43071187B990240', 'Wayne Watson', 'Wisner, LA', None, None),
#  ('ARL7K851187B99ACD2', 'Andy Andy', None, None, None),
# ...

# %%
# %sql SELECT * FROM time limit 10;

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).

# %%
# %sql select * from songplays where song_id is not null;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 1 rows affected.
# [(4627, datetime.datetime(2018, 11, 21, 21, 56, 47, 796000), 15, 'paid', 'SOZCTXZ12AB0182364', 'AR5KOSW1187FB35FF4', 818, 'Chicago-Naperville-Elgin, IL-IN-WI', 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36')]

# %%
#%sql select * from songs join artists on songs.artist_id = artists.artist_id;
# %sql select *  from songs  join artists    on songs.artist_id = artists.artist_id where songs.song_id = 'SOINLJW12A8C13314C';
#%sql update songs set title = 'Fly Like An Eagle',duration = '254.06649' where song_id = 'SOINLJW12A8C13314C';
#%sql update artists set name = 'Seal' where artist_id = 'AR8IEZO1187B99055E';
# %sql commit;

# %%
# %sql select songs.song_id,artists.artist_id from songs join artists  on songs.artist_id = artists.artist_id where songs.title = 'Ain''t No Sunshine'   and artists.name = 'Sydney Youngblood'  and songs.duration = 238.07955

# %%
# %sql select user_agent,count(*) from songplays group by user_agent;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 40 rows affected.
# [('Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36', 577),
#  ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_3) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36', 5),
#  ('Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36', 573),
#  ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.94 Safari/537.36', 45),
#  ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10.7; rv:31.0) Gecko/20100101 Firefox/31.0', 9),
#  ('Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.102 Safari/537.36', 15),
#  ('Mozilla/5.0 (Windows NT 6.3; WOW64; Trident/7.0; rv:11.0) like Gecko', 1),
#  ('Mozilla/5.0 (Macintosh; Intel Mac OS X 10.9; rv:31.0) Gecko/20100101 Firefox/31.0', 443),
# ...

# %%
# %sql select * from users order by user_id;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 96 rows affected.
# [(2, 'Jizelle', 'Benjamin', 'F', 'free'),
#  (3, 'Isaac', 'Valdez', 'M', 'free'),
#  (4, 'Alivia', 'Terrell', 'F', 'free'),
#  (5, 'Elijah', 'Davis', 'M', 'free'),
#  (6, 'Cecilia', 'Owens', 'F', 'free'),
#  (7, 'Adelyn', 'Jordan', 'F', 'free'),
#  (8, 'Kaylee', 'Summers', 'F', 'free'),
#  (9, 'Wyatt', 'Scott', 'M', 'free'),
#  (10, 'Sylvie', 'Cruz', 'F', 'free'),
#  (11, 'Christian', 'Porter', 'F', 'free'),
#  (12, 'Austin', 'Rosales', 'M', 'free'),
#  (13, 'Ava', 'Robinson', 'F', 'free'),
#  (14, 'Theodore', 'Harris', 'M', 'free'),
#  (15, 'Lily', 'Koch', 'F', 'paid'),
#  (16, 'Rylan', 'George', 'M', 'paid'),
#  (17, 'Makinley', 'Jones', 'F', 'free'),
#  (18, 'Jacob', 'Rogers', 'M', 'free'),
#  (19, 'Zachary', 'Thomas', 'M', 'free'),
#  (20, 'Aiden', 'Ramirez', 'M', 'paid'),
#  (22, 'Sean', 'Wilson', 'F', 'free'),
#  (23, 'Morris', 'Gilmore', 'M', 'free'),
#  (24, 'Layla', 'Griffin', 'F', 'paid'),
# ...

# %%
# %sql insert into users(user_id,first_name,last_name,gender,level) values ('49','Chloe','Cuevas','F','free') on conflict(user_id) do update set level = EXCLUDED.level

# %%
# %sql select * from users where user_id = '49';

# %%
# %sql insert into users(user_id,first_name,last_name,gender,level) values ('49','Chloe','Cuevas','F','paid') on conflict(user_id) do nothing;
